# %% [markdown]
# **Befolkningsprognos Umeå 2045**

# %% [markdown]
# Umeås historiska befolkningsutveckling

# %%
#visualisering av umeås historiska befolkningsutveckling användninga av histogram

# %% [markdown]
# Analys av visualisering

# %%
#visualisering av arbetsmarkand över tid i umeå kommun

# %% [markdown]
# Generllet om arbetsmarknad

# %%
#arbetsmarkand i umeå kommun per zon utveckling över tid

# %% [markdown]
# Diskutera intressanta områden

# %% [markdown]
# **Framtidsscenario**
